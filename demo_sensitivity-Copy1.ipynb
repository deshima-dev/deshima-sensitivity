# %% [markdown]
# # DESHIMA 2.0 sensitivity calculation

# %% [markdown]
# ## Setup

# %%
# IPython extension to reload modules before executing user code.
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
