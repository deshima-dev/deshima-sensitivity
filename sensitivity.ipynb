# %% [markdown]
# # DESHIMA 2.0 sensitivity calculator (beta)

# %% [markdown]
# ![DESHIMA logo](http://deshima.ewi.tudelft.nl/image/deshima_logo.png)

# %% [markdown]
# ## About the Interactive Notebook on Binder
#
# - If you have launched this in `Binder`, it an take a few minutes before the interactive notebook is loaded.
# - Until the interactive notebook is launched, you will see a *static* version of the notebook (you cannot edit variable or execute the code). This might be what you are seeing now. Please be patient, the interactive notebook will be ready while get yourself a warm cup of tea.
# - If you are viewing the static notebook on github, and want to launch the interactive version, launch `Binder` from this link:
#     - ![Binder](https://mybinder.org/badge_logo.svg)

# %% [markdown]
# ## Minimum detectable line flux
#
# This script calculates the minimum detectable line flux (MDLF) of DESHIMA 2.0.
#
# - The user can change some parameters related to observation.
# - After execution, the plot will be updated, and the sensitivity curves for baseline and goal performances can be downloaded as a csv file.
# - The calculation is based on the DESHIMA 2.0 hardware requirements, which can be found [here](https://deshima.kibe.la/shared/entries/ff96eb1f-ef80-41e2-adf8-178769a72e3f).

# %%
# To execute, select this cell and type "Shift+Enter"
# The download link for the CSV file will appear below this cell.

# %matplotlib inline
import desim as dsm

dsm.deshima_sensitivity_simple(
        pwv = 0.5,      # Precipitable Water Vapor in mm
        EL = 60.,       # Elevation angle in degrees
        snr = 5.,       # Target S/N of the detection
        obs_hours = 8.  # Observation time in hours, including ON-OFF and calibration overhead
        )
# Out:
# <a download="MDLF.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
